# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import seaborn as sb

# %%
df = pd.read_csv("dataset/Patients_V1_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)

# %%
df.shape
# Out:
# (6631, 1356)

# %%
df.describe()
# Out:
#        number_in_K1    id_patient    birthyear  postal_code_K1  \
# count   6631.000000  6.631000e+03  6631.000000     6631.000000
# mean    4849.043583  5.528867e+07  1984.585734       62.367818
# std     2793.419302  2.595205e+07    13.647938       33.193086
# min        1.000000  1.000752e+07  1935.000000        1.000000
# 25%     2465.500000  3.340759e+07  1974.000000       28.000000
# 50%     4868.000000  5.564993e+07  1986.000000       82.000000
# 75%     7279.000000  7.809693e+07  1996.000000       88.000000
# max     9667.000000  9.999193e+07  2009.000000       99.000000
#
#        total_nr_cycles  nr_dc_before_K1  nr_pc_before_K1      ID_PC_K1  \
# count      6631.000000           6631.0      6631.000000   6631.000000
# mean          3.254411              0.0         0.080682  22128.557080
# std           3.464359              0.0         0.299783  14242.344898
# min           1.000000              0.0         0.000000    101.000000
# ...

# %%
df.head(12)
# Out:
#    export_date  number_in_K1  id_patient date_registration    gender  \
# 0   2026-03-02             1    10007520        2023-06-22  weiblich
# 1   2026-03-02             2    10022137        2021-10-24  männlich
# 2   2026-03-02             6    10070992        2023-05-22  weiblich
# 3   2026-03-02             7    10072456        2025-01-14  weiblich
# 4   2026-03-02             8    10076150        2020-10-26  weiblich
# 5   2026-03-02             9    10076484        2023-09-15  weiblich
# 6   2026-03-02            12    10098623        2023-03-28  weiblich
# 7   2026-03-02            13    10100880        2023-03-14  weiblich
# 8   2026-03-02            15    10111638        2025-01-14  weiblich
# 9   2026-03-02            16    10112389        2025-04-09  weiblich
# 10  2026-03-02            17    10112458        2025-05-16  männlich
# 11  2026-03-02            18    10125810        2025-05-13  weiblich
#
# ...

# %%
df.tail(12)
# Out:
#      export_date  number_in_K1  id_patient date_registration    gender  \
# 6619  2026-03-02          9652    99833852        2025-01-15  weiblich
# 6620  2026-03-02          9653    99840155        2021-08-19  weiblich
# 6621  2026-03-02          9654    99843590        2024-09-05  weiblich
# 6622  2026-03-02          9655    99847050        2023-08-11  weiblich
# 6623  2026-03-02          9657    99855848        2025-11-14  weiblich
# 6624  2026-03-02          9658    99859866        2025-05-06  weiblich
# 6625  2026-03-02          9659    99879224        2025-05-26  weiblich
# 6626  2026-03-02          9660    99940176        2025-12-25  männlich
# 6627  2026-03-02          9661    99946992        2021-08-10  männlich
# 6628  2026-03-02          9662    99947460        2025-05-20  weiblich
# 6629  2026-03-02          9665    99979901        2025-09-23  weiblich
# 6630  2026-03-02          9667    99991933        2025-09-15  weiblich
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6631 entries, 0 to 6630
# Columns: 1356 entries, export_date to age_reg
# dtypes: bool(13), float64(262), int64(660), object(421)
# memory usage: 68.0+ MB

# %%
df.columns[:20]
# Out:
# Index(['export_date', 'number_in_K1', 'id_patient', 'date_registration',
#        'gender', 'birthyear', 'postal_code_K1', 'date_first_pc',
#        'date_first_dc', 'total_nr_cycles', 'nr_dc_before_K1',
#        'nr_pc_before_K1', 'control_type_K1', 'ID_PC_K1', 'ID_DC_K1',
#        'state_dc_K1', 'id_center_K1', 'date_pc_K1', 'date_dc_K1',
#        'cluster_module_K1'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 1356
