# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import seaborn as sb
# !pip install ydata-profiling
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# ...

# %%
df1 = pd.read_csv("dataset/attack/Attacks_V1_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df2 = pd.read_csv("dataset/attack/Attacks_V2_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df3 = pd.read_csv("dataset/attack/Attacks_V3_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df4 = pd.read_csv("dataset/attack/Attacks_V4_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df5 = pd.read_csv("dataset/attack/Attacks_V5_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df6 = pd.read_csv("dataset/attack/Attacks_V6_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df7 = pd.read_csv("dataset/attack/Attacks_V7_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df8 = pd.read_csv("dataset/attack/Attacks_V8_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df9 = pd.read_csv("dataset/attack/Attacks_V9_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df10 = pd.read_csv("dataset/attack/Attacks_V10_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df11 = pd.read_csv("dataset/attack/Attacks_V11_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df12 = pd.read_csv("dataset/attack/Attacks_V12_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df13 = pd.read_csv("dataset/attack/Attacks_V13_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df14 = pd.read_csv("dataset/attack/Attacks_V14_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df15 = pd.read_csv("dataset/attack/Attacks_V15_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df16 = pd.read_csv("dataset/attack/Attacks_V16_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df17 = pd.read_csv("dataset/attack/Attacks_V17_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df18 = pd.read_csv("dataset/attack/Attacks_V18_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df19 = pd.read_csv("dataset/attack/Attacks_V19_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df20 = pd.read_csv("dataset/attack/Attacks_V20_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df21 = pd.read_csv("dataset/attack/Attacks_V21_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df22 = pd.read_csv("dataset/attack/Attacks_V22_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
df23 = pd.read_csv("dataset/attack/Attacks_V23_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)
#df_app= pd.read_csv("dataset/Attacks_AppOnly_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)

# %%
df1["visit"] = 1
df2["visit"] = 2
df3["visit"] = 3
df4["visit"] = 4
df5["visit"] = 5
df6["visit"] = 6
df7["visit"] = 7
df8["visit"] = 8
df9["visit"] = 9
df10["visit"] = 10
df12["visit"] = 11
df13["visit"] = 12
df14["visit"] = 13
df15["visit"] = 14
df16["visit"] = 15
df17["visit"] = 16
df17["visit"] = 17
df18["visit"] = 18
df19["visit"] = 19
df20["visit"] = 20
df21["visit"] = 21
df22["visit"] = 22
df23["visit"] = 23
#df_app["visit"] = 0

# %%
#ignore index(reorder the rows from 0 to n ) during concatenation
df_final = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23],axis=0,ignore_index=True)

# %%
df_final = df_final.sort_values(["patient_info_id"])

# %%
df_final.shape
# Out:
# (4575646, 53)

# %%
df_final.head()
# Out:
#              id  headache  migraine attack_time  intensity  duration  \
# 279640  1870355      True     False  2023-07-21          7       480
# 342378  2505321      True      True  2023-11-21          8       780
# 340188  2483044      True      True  2023-11-18         10       960
# 524128  4700587      True     False  2024-09-08          6       360
# 306407  2131030      True     False  2023-09-14          3       360
#
#         symptoms_both_side_headache  symptoms_one_side_headache  \
# 279640                         True                       False
# 342378                         True                       False
# 340188                         True                       False
# 524128                        False                        True
# 306407                         True                       False
#
#         symptoms_pulsating_headache  symptoms_dull_headache  ...  Opoide_Eff  \
# 279640                         True                    True  ...         NaN
# ...

# %%
sample=df_final.sample(5000)

# %%
#data profiling
from ydata_profiling import ProfileReport
report = ProfileReport(sample, title="Post-Merge Profile", explorative=True)
report.to_file("profile_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
relevant_columns=["id","patient_info_id","headache","attack_time","intensity","duration","symptoms_both_side_headache", "symptoms_one_side_headache",
       "symptoms_pulsating_headache", "symptoms_dull_headache","weekday","visit"]
req_df=df_final[relevant_columns]

# %%
#req_df.head(30)
req_df[1000:2000]
# Out:
#                id  patient_info_id  headache attack_time  intensity  duration  \
# 1506229  10873540         10076484      True  2025-12-27          5      1440
# 2390283   9368722         10076484      True  2025-09-22          6      1440
# 2700637   6138217         10076484      True  2025-01-27          9      1440
# 2749654   8482770         10076484      True  2025-07-25          3      1440
# 1520226  11374700         10076484      True  2026-01-20          7      1440
# ...           ...              ...       ...         ...        ...       ...
# 952428   10982890         10076484      True  2025-12-29          8      1440
# 2705456   6338647         10076484      True  2025-02-13          8      1440
# 768225    8077860         10076484      True  2025-06-15          6      1440
# 1500778  10682993         10076484      True  2025-12-12          6      1440
# 466323    3958937         10076484      True  2024-06-13          8      1440
#
# ...

# %%
req_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#req_df = req_df.set_index(["id"])
req_df.groupby(["patient_info_id"]).size().sort_values(ascending=False)
# Out:
# patient_info_id
# 45861150    1974
# 58668734    1937
# 25124162    1906
# 79404720    1837
# 78562347    1787
#             ...
# 43054467       1
# 43051709       1
# 73254706       1
# 43179664       1
# 99963250       1
# Length: 64212, dtype: int64

# %%
req_df.duplicated(subset=["patient_info_id", "attack_time"]).sum()
# Out:
# np.int64(0)

# %%
req_df = req_df.drop_duplicates(subset=["patient_info_id","attack_time","weekday"])
req_df.shape
# Out:
# (4066498, 11)

# %%
req_df.head(60)
# Out:
#      patient_info_id  headache attack_time  intensity  duration  \
# id
# 117         72741515      True  2020-06-08          4       480
# 118         72741515      True  2020-06-09          5       360
# 124         94719087      True  2020-06-25          8       360
# 125         94719087      True  2020-06-26          5       180
# 127         44203359      True  2020-06-19         10       300
# 128         44203359      True  2020-06-20         10       300
# 129         44203359      True  2020-06-21         10       480
# 130         44203359      True  2020-06-22          6       180
# 131         44203359      True  2020-06-23         10       840
# 133         44203359      True  2020-06-24          1      1440
# 134         44203359      True  2020-06-25          1      1440
# 135         94719087      True  2020-06-27          3       240
# 153         14736818      True  2020-06-28          7       300
# 154         14736818      True  2020-06-20          3       300
# ...

# %%
req_df["visit"].value_counts()
# Out:
# visit
# 0.0    3070159
# 1.0     996339
# Name: count, dtype: int64

# %%
#check if duplicated remains
req_df.duplicated(subset=["id","attack_time"]).sum()
# Out:
# np.int64(0)

# %%
req_df = req_df.set_index(["patient_info_id"])

# %%
req_df.head(60)
# Out:
#                  headache attack_time  intensity  duration  \
# patient_info_id
# 72741515             True  2020-06-08          4       480
# 72741515             True  2020-06-09          5       360
# 94719087             True  2020-06-25          8       360
# 94719087             True  2020-06-26          5       180
# 44203359             True  2020-06-19         10       300
# 44203359             True  2020-06-20         10       300
# 44203359             True  2020-06-21         10       480
# 44203359             True  2020-06-22          6       180
# 44203359             True  2020-06-23         10       840
# 44203359             True  2020-06-24          1      1440
# 44203359             True  2020-06-25          1      1440
# 94719087             True  2020-06-27          3       240
# 14736818             True  2020-06-28          7       300
# 14736818             True  2020-06-20          3       300
# 14736818             True  2020-06-19          7       960
# ...
