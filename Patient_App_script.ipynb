# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import seaborn as sb

# %%
df = pd.read_csv("dataset/Patients_AppOnly_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)

# %%
df.shape
# Out:
# (73303, 1356)

# %%
df.columns
# Out:
# Index(['export_date', 'number_in_K0', 'id_patient', 'date_registration',
#        'gender', 'birthyear', 'postal_code_K0', 'date_first_pc',
#        'date_first_dc', 'total_nr_cycles',
#        ...
#        'Fibromyalgie_K0', 'Bruxismus..Zähneknirschen._K0',
#        'Chronischer.Schmerz.bei.Arthrose...Knie_K0',
#        'Chronischer.Schmerz.bei.Arthrose...Hüfte_K0',
#        'Chronischer.Schmerz.bei.Arthrose...Finger_K0',
#        'Chronischer.Schmerz.bei.Arthrose...Andere_K0',
#        'Andere.Erkrankungen_K0', 'Operationen_K0', 'number_begleit_Medi_K0',
#        'age_reg'],
#       dtype='object', length=1356)
