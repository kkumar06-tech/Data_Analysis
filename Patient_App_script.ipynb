# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import seaborn as sb

# %%
df = pd.read_csv("dataset/Patients_AppOnly_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)

# %%
df.shape
# Out:
# (73303, 1356)

# %%
df.columns[60:100]
# Out:
# Index(['vr12_msc_K0', 'vr12_psc_K0', 'gvas_result_K0', 'pgic_result_K0',
#        'chiq_result_K0', 'firsttime_K0', 'headache_days_per_month_K0',
#        'headache_days_severe_per_month_K0', 'days_medication_K0',
#        'intensity_K0', 'days_lost_work_K0', 'days_lost_household_K0',
#        'days_doctor_K0', 'days_ER_K0', 'days_hospital_K0', 'dia_migraine_K0',
#        'dia_tension_headache_K0', 'dia_cluster_headache_K0',
#        'dia_drug_induced_headache_K0', 'dia_cervical_spine_disorder_K0',
#        'dia_trigeminal_neuralgia_K0', 'dia_other_K0',
#        'attack_count_cluster_K0', 'medication_acute_count_cluster_K0',
#        'avg_attack_duration_mins_cluster_K0',
#        'avg_attack_intensity_cluster_K0', 'symptoms_side_cluster_K0',
#        'Clinical_checks_unauf_K0', 'Clinical_checks_auf_K0',
#        'Clinical_checks_nichtd_K0', 'Clinical_kein_check_K0',
#        'number_of_diagnoses_K0', 'name_1_K0', 'icd10_1_K0', 'ichd3_1_K0',
# ...

# %%
relevant_columns=['export_date', 'number_in_K0', 'id_patient', 'date_registration',
       'gender', 'birthyear', 'postal_code_K0', 'date_first_pc',
       'date_first_dc', 'total_nr_cycles', 'nr_dc_before_K0',
       'nr_pc_before_K0', 'control_type_K0', 'ID_PC_K0', 'ID_DC_K0',
       'state_dc_K0', 'id_center_K0', 'date_pc_K0', 'date_dc_K0',
       'cluster_module_K0','entries_app', 'first_app_entry',
       'last_app_entry', 'period_use_app', 'entries_app_Android_K0',
       'entries_app_iOS_K0', 'headache_entries_app', 'migraine_entries_app',
       'cluster_entries_app', 'cluster_first_app_entry',
       'cluster_last_app_entry', 'cluster_period_use_app',
       'cluster_entries_app_Android_K0', 'cluster_entries_app_iOS_K0',
       'cluster_headache_entries_app','firsttime_K0', 'headache_days_per_month_K0',
       'headache_days_severe_per_month_K0', 'days_medication_K0',
       'intensity_K0', 'days_lost_work_K0', 'days_lost_household_K0',
       'days_doctor_K0', 'days_ER_K0', 'days_hospital_K0', 'dia_migraine_K0',
       'dia_tension_headache_K0', 'dia_cluster_headache_K0',
       'dia_drug_induced_headache_K0','dia_cervical_spine_disorder_K0',
       'dia_trigeminal_neuralgia_K0', 'dia_other_K0',
       'attack_count_cluster_K0', 'medication_acute_count_cluster_K0',
       'avg_attack_duration_mins_cluster_K0',
       'avg_attack_intensity_cluster_K0', 'symptoms_side_cluster_K0',
       'Clinical_checks_unauf_K0', 'Clinical_checks_auf_K0',
       'Clinical_checks_nichtd_K0', 'Clinical_kein_check_K0']

# %%
req_columns=df[relevant_columns]
req_columns.head()
# Out:
#   export_date  number_in_K0  id_patient date_registration    gender  \
# 0  2026-03-02            12    10005064        2024-02-01  weiblich
# 1  2026-03-02            13    10005187        2024-04-27  weiblich
# 2  2026-03-02            14    10005708        2021-09-17  männlich
# 3  2026-03-02            15    10005818        2025-03-16  weiblich
# 4  2026-03-02            17    10009199        2025-09-30  männlich
#
#    birthyear  postal_code_K0 date_first_pc  date_first_dc  total_nr_cycles  \
# 0       2003              70           NaN            NaN                0
# 1       2003              44           NaN            NaN                0
# 2       1992              81           NaN            NaN                0
# 3       1968              79           NaN            NaN                0
# 4       1984              90           NaN            NaN                0
#
#    ...  dia_other_K0  attack_count_cluster_K0  \
# 0  ...           NaN                      NaN
# ...
