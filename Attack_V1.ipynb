# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import seaborn as sb
# !pip install ydata-profiling
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# Requirement already satisfied: ydata-profiling in /opt/conda/lib/python3.10/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (1.15.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /opt/conda/lib/python3.10/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (2.2.6)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling) (0.61.2)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from imagehash==4.3.2->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in /opt/conda/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
df = pd.read_csv("dataset/attack/Attacks_V1_02-03-2026.csv",sep=';', low_memory=False)

# %%
df.shape
# Out:
# (996339, 52)

# %%
df.columns
# Out:
# Index(['id', 'headache', 'migraine', 'attack_time', 'intensity', 'duration',
#        'symptoms_both_side_headache', 'symptoms_one_side_headache',
#        'symptoms_pulsating_headache', 'symptoms_dull_headache',
#        'symptoms_increased_during_physical_activity', 'symptoms_nausea',
#        'symptoms_vomiting', 'symptoms_light_sensitivity',
#        'symptoms_noise_sensitivity', 'symptoms_smell_sensitivity',
#        'symptoms_vertigo', 'symptoms_concentration_disorder',
#        'symptoms_tiredness', 'symptoms_aura', 'symptoms_aura_vision',
#        'symptoms_aura_emotion', 'symptoms_aura_speech',
#        'symptoms_aura_paralysis', 'effects_unfit_for_work',
#        'effects_unfit_for_household_recreation', 'effects_doctor',
#        'effects_emergency_room', 'effects_hospital', 'comment_menstruation',
#        'patient_info_id', 'source_version_id', 'api_version_id', 'create_date',
#        'modified_date', 'nMed', 'Triptane_Geb', 'Triptane_Eff',
#        'EinfacheSM_Geb', 'EinfacheSM_Eff', 'Uebelkeit_Geb', 'Uebelkeit_Eff',
#        'Opoide_Geb', 'Opoide_Eff', 'Kombi_Geb', 'Kombi_Eff',
#        'DitaneGepante_Geb', 'DitaneGepante_Eff', 'Ergotamin_Geb',
#        'Ergotamin_Eff', 'medication', 'weekday'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     id  headache  migraine attack_time  intensity  duration  \
# 0  124      True      True  2020-06-25          8       360
# 1  125      True      True  2020-06-26          5       180
# 2  135      True      True  2020-06-27          3       240
# 3  172      True      True  2020-06-29          3       120
# 4  179      True     False  2020-06-30          5       360
# 5  186      True      True  2020-07-01          3        60
# 6  189      True     False  2020-07-01          5       420
# 7  194      True     False  2020-07-02          5       300
# 8  199      True      True  2020-07-02          2        60
# 9  215      True     False  2020-07-03          3      1440
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                        False                        True
# 1                        False                        True
# 2                        False                        True
# 3                        False                        True
# 4                        False                       False
# 5                        False                        True
# 6                        False                       False
# 7                        False                       False
# 8                        False                        True
# 9                        False                       False
#
#    symptoms_pulsating_headache  symptoms_dull_headache  ...  Opoide_Geb  \
# 0                         True                   False  ...         0.0
# 1                         True                   False  ...         0.0
# 2                         True                   False  ...         0.0
# 3                        False                   False  ...         0.0
# 4                        False                   False  ...         NaN
# 5                        False                   False  ...         0.0
# 6                        False                   False  ...         NaN
# 7                        False                   False  ...         NaN
# 8                        False                   False  ...         0.0
# 9                        False                   False  ...         NaN
#
#    Opoide_Eff  Kombi_Geb         Kombi_Eff  DitaneGepante_Geb  \
# 0         0,0        0.0  0,00000000000000                0.0
# 1         0,0        0.0  0,00000000000000                0.0
# 2         0,0        0.0  0,00000000000000                0.0
# 3         0,0        0.0  0,00000000000000                0.0
# 4         NaN        NaN               NaN                NaN
# 5         0,0        0.0  0,00000000000000                0.0
# 6         NaN        NaN               NaN                NaN
# 7         NaN        NaN               NaN                NaN
# 8         0,0        0.0  0,00000000000000                0.0
# 9         NaN        NaN               NaN                NaN
#
#    DitaneGepante_Eff  Ergotamin_Geb  Ergotamin_Eff  medication     weekday
# 0                0.0            0.0            0,0        True  Donnerstag
# 1                0.0            0.0            0,0        True     Freitag
# 2                0.0            0.0            0,0        True     Samstag
# 3                0.0            0.0            0,0        True      Montag
# 4                NaN            NaN            NaN       False    Dienstag
# 5                0.0            0.0            0,0        True    Mittwoch
# 6                NaN            NaN            NaN       False    Mittwoch
# 7                NaN            NaN            NaN       False  Donnerstag
# 8                0.0            0.0            0,0        True  Donnerstag
# 9                NaN            NaN            NaN       False     Freitag
#
# [10 rows x 52 columns]

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(df, title="Post-Merge Profile", explorative=True)
report.to_file("profile_report_A1.html")
# Out:
# /tmp/ipykernel_110/9752537.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py:97, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      92 future_to_col = {
#      93     executor.submit(describe_column, name, series): name  # type:ignore
#      94     for name, series in df.items()
#      95 }
# ---> 97 for future in tqdm(future_to_col.keys(), total=len(future_to_col)):
#      98     name, description = future.result()
#
# File /opt/conda/lib/python3.10/site-packages/tqdm/std.py:1096, in tqdm.__init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, write_bytes, lock_args, nrows, colour, delay, gui, **kwargs)
#    1094 if not gui:
#    1095     # Initialize the screen printer
# -> 1096     self.sp = self.status_printer(self.fp)
#    1097     if delay <= 0:
#
# File /opt/conda/lib/python3.10/site-packages/tqdm/std.py:448, in tqdm.status_printer(file)
#     447 if fp in (sys.stderr, sys.stdout):
# --> 448     getattr(sys.stderr, 'flush', lambda: None)()
#     449     getattr(sys.stdout, 'flush', lambda: None)()
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     608 # and give a timeout to avoid
# --> 609 if not evt.wait(self.flush_timeout):
#     610     # write directly to __stderr__ instead of warning because
#     611     # if this is happening sys.stderr may be the problem.
#     612     print("IOStream.flush timed out", file=sys.__stderr__)
#
# File /opt/conda/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /opt/conda/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     323 if timeout > 0:
# --> 324     gotit = waiter.acquire(True, timeout)
#     325 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 from ydata_profiling import ProfileReport
#       2 report = ProfileReport(df, title="Post-Merge Profile", explorative=True)
# ----> 3 report.to_file("profile_report_A1.html")
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)
#     496
#     497     """
# --> 498     return self.html
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)
#     426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/profile_report.py:270, in ProfileReport.description_set(self)
#     267 @property
#     268 def description_set(self) -> BaseDescription:
#     269     if self._description_set is None:
# --> 270         self._description_set = describe_df(
#     271             self.config,
#     272             self.df,
#     273             self.summarizer,
#     274             self.typeset,
#     275             self._sample,
#     276         )
#     277     return self._description_set
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/model/describe.py:89, in describe(config, df, summarizer, typeset, sample)
#      87 # Variable-specific
#      88 pbar.total += len(df.columns)
# ---> 89 series_description = get_series_descriptions(
#      90     config, df, summarizer, typeset, pbar
#      91 )
#      93 pbar.set_postfix_str("Get variable types")
#      94 pbar.total += 1
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/model/summary.py:62, in get_series_descriptions(config, df, summarizer, typeset, pbar)
#      54 def get_series_descriptions(
#      55     config: Settings,
#      56     df: Any,
#    (...)
#      59     pbar: tqdm,
#      60 ) -> dict:
#      61     if isinstance(df, pd.DataFrame):
# ---> 62         return pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      63     elif isinstance(df, sparkDataFrame):  # type: ignore
#      64         return get_series_descriptions_spark(config, df, summarizer, typeset, pbar)
#
# File /opt/conda/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py:91, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      85 pool_size = (
#      86     config.pool_size if config.pool_size > 0 else multiprocessing.cpu_count()
#      87 )
#      89 series_description = {}
# ---> 91 with ThreadPoolExecutor(max_workers=pool_size) as executor:
#      92     future_to_col = {
#      93         executor.submit(describe_column, name, series): name  # type:ignore
#      94         for name, series in df.items()
#      95     }
#      97     for future in tqdm(future_to_col.keys(), total=len(future_to_col)):
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /opt/conda/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/conda/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
df['duration'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 996339 entries, 0 to 996338
# Series name: duration
# Non-Null Count   Dtype
# --------------   -----
# 996339 non-null  int64
# dtypes: int64(1)
# memory usage: 7.6 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby(["patient_info_id"]).size().sort_values(ascending=False)
# Out:
# patient_info_id
# 25124162    1906
# 79404720    1837
# 78562347    1787
# 23072369    1771
# 79983539    1737
#             ...
# 79273392       1
# 81042397       1
# 81962934       1
# 78156623       1
# 78482647       1
# Length: 5401, dtype: int64

# %%
relevant_columns=["id","patient_info_id","headache","migraine","attack_time","duration","symptoms_both_side_headache", "symptoms_one_side_headache",
       "symptoms_pulsating_headache", "symptoms_dull_headache","weekday"]
req_df=df[relevant_columns].copy()

# %%
req_df.dtypes
#attack time is object need to change it
#weekday is also object needto change it maybe some kind of encoding
# Out:
# id                              int64
# patient_info_id                 int64
# headache                         bool
# migraine                         bool
# attack_time                    object
# duration                        int64
# symptoms_both_side_headache      bool
# symptoms_one_side_headache       bool
# symptoms_pulsating_headache      bool
# symptoms_dull_headache           bool
# weekday                        object
# dtype: object

# %%
req_df["attack_time"] = pd.to_datetime(req_df["attack_time"])
req_df["weekday"].unique()
# Out:
# array(['Donnerstag', 'Freitag', 'Samstag', 'Montag', 'Dienstag',
#        'Mittwoch', 'Sonntag'], dtype=object)

# %%
order = ["Montag","Dienstag","Mittwoch","Donnerstag","Freitag","Samstag","Sonntag"]
req_df["weekday"] = pd.Categorical(req_df["weekday"], categories=order, ordered=True)
req_df.dtypes
# Out:
# id                                      int64
# patient_info_id                         int64
# headache                                 bool
# migraine                                 bool
# attack_time                    datetime64[ns]
# duration                                int64
# symptoms_both_side_headache              bool
# symptoms_one_side_headache               bool
# symptoms_pulsating_headache              bool
# symptoms_dull_headache                   bool
# weekday                              category
# dtype: object

# %%
req_df.head(5)
# Out:
#     id  patient_info_id  headache  migraine attack_time  duration  \
# 0  124         94719087      True      True  2020-06-25       360
# 1  125         94719087      True      True  2020-06-26       180
# 2  135         94719087      True      True  2020-06-27       240
# 3  172         94719087      True      True  2020-06-29       120
# 4  179         70854341      True     False  2020-06-30       360
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                        False                        True
# 1                        False                        True
# 2                        False                        True
# 3                        False                        True
# 4                        False                       False
#
#    symptoms_pulsating_headache  symptoms_dull_headache     weekday
# 0                         True                   False  Donnerstag
# 1                         True                   False     Freitag
# 2                         True                   False     Samstag
# 3                        False                   False      Montag
# 4                        False                   False    Dienstag

# %%
# Count missing values in each column
print(req_df.isnull().sum())
# Out:
# id                             0
# patient_info_id                0
# headache                       0
# migraine                       0
# attack_time                    0
# duration                       0
# symptoms_both_side_headache    0
# symptoms_one_side_headache     0
# symptoms_pulsating_headache    0
# symptoms_dull_headache         0
# weekday                        0
# dtype: int64

# %%
print(req_df.isna().any())
# Out:
# id                             False
# patient_info_id                False
# headache                       False
# migraine                       False
# attack_time                    False
# duration                       False
# symptoms_both_side_headache    False
# symptoms_one_side_headache     False
# symptoms_pulsating_headache    False
# symptoms_dull_headache         False
# weekday                        False
# dtype: bool

# %% [raw]
# req_df.shape

# %%
#shape is 996339 * 10
req_df['id'].nunique()
# Out:
# 996339

# %%
req_df = req_df.sort_values(["patient_info_id", "attack_time"])
req_df.head(5)
# Out:
#              id  patient_info_id  headache  migraine attack_time  duration  \
# 265160  1734884         10007520      True     False  2023-06-21       900
# 266184  1744944         10007520      True     False  2023-06-24       300
# 266823  1750577         10007520      True     False  2023-06-25       480
# 267168  1753437         10007520      True     False  2023-06-26       300
# 267693  1757973         10007520      True     False  2023-06-27       900
#
#         symptoms_both_side_headache  symptoms_one_side_headache  \
# 265160                         True                       False
# 266184                         True                       False
# 266823                         True                       False
# 267168                         True                       False
# 267693                         True                       False
#
#         symptoms_pulsating_headache  symptoms_dull_headache   weekday
# 265160                         True                   False  Mittwoch
# 266184                         True                   False   Samstag
# 266823                         True                   False   Sonntag
# 267168                         True                   False    Montag
# 267693                         True                    True  Dienstag

# %%
req_df.set_index("id")
# Out:
#          patient_info_id  headache  migraine attack_time  duration  \
# id
# 1734884         10007520      True     False  2023-06-21       900
# 1744944         10007520      True     False  2023-06-24       300
# 1750577         10007520      True     False  2023-06-25       480
# 1753437         10007520      True     False  2023-06-26       300
# 1757973         10007520      True     False  2023-06-27       900
# ...                  ...       ...       ...         ...       ...
# 9250131         99991933      True      True  2025-09-03      1440
# 9250161         99991933      True     False  2025-09-04      1440
# 9273119         99991933      True      True  2025-09-05      1440
# 9273127         99991933      True      True  2025-09-06      1440
# 9273134         99991933      True      True  2025-09-07      1440
#
#          symptoms_both_side_headache  symptoms_one_side_headache  \
# id
# 1734884                         True                       False
# 1744944                         True                       False
# 1750577                         True                       False
# 1753437                         True                       False
# 1757973                         True                       False
# ...                              ...                         ...
# 9250131                        False                        True
# 9250161                         True                       False
# 9273119                        False                        True
# 9273127                        False                        True
# 9273134                        False                       False
#
#          symptoms_pulsating_headache  symptoms_dull_headache     weekday
# id
# 1734884                         True                   False    Mittwoch
# 1744944                         True                   False     Samstag
# 1750577                         True                   False     Sonntag
# 1753437                         True                   False      Montag
# 1757973                         True                    True    Dienstag
# ...                              ...                     ...         ...
# 9250131                         True                   False    Mittwoch
# 9250161                        False                    True  Donnerstag
# 9273119                         True                   False     Freitag
# 9273127                         True                   False     Samstag
# 9273134                         True                   False     Sonntag
#
# [996339 rows x 10 columns]

# %%
#check the numeric columns for irregularity

# Convert to numeric, invalid entries become NaN
req_df["duration_check"] = pd.to_numeric(req_df["duration"], errors='coerce')

# Rows where conversion failed
invalid_rows = req_df[req_df["duration_check"].isna()]
print("Rows with invalid duration values:")
print(invalid_rows)
# Out:
# Rows with invalid duration values:
# Empty DataFrame
# Columns: [id, patient_info_id, headache, migraine, attack_time, duration, symptoms_both_side_headache, symptoms_one_side_headache, symptoms_pulsating_headache, symptoms_dull_headache, weekday, duration_check]
# Index: []

# %%
invalid_weekday = req_df[~req_df["weekday"].apply(lambda x: isinstance(x, str))]
print("Rows with non-string weekday:")
print(invalid_weekday)
# Out:
# Rows with non-string weekday:
# Empty DataFrame
# Columns: [id, patient_info_id, headache, migraine, attack_time, duration, symptoms_both_side_headache, symptoms_one_side_headache, symptoms_pulsating_headache, symptoms_dull_headache, weekday, duration_check]
# Index: []

# %%
req_df.nunique()
# Out:
# id                             996339
# patient_info_id                  5401
# headache                            1
# migraine                            2
# attack_time                      2062
# duration                           24
# symptoms_both_side_headache         2
# symptoms_one_side_headache          2
# symptoms_pulsating_headache         2
# symptoms_dull_headache              2
# weekday                             7
# duration_check                     24
# dtype: int64

# %%
req_df[req_df["patient_info_id"] == 25124162].sort_values("attack_time")
# Out:
#               id  patient_info_id  headache  migraine attack_time  duration  \
# 37           425         25124162      True     False  2020-07-07       540
# 38           426         25124162      True     False  2020-07-08       360
# 39           427         25124162      True     False  2020-07-09       360
# 40           428         25124162      True      True  2020-07-10       840
# 41           429         25124162      True     False  2020-07-11        60
# ...          ...              ...       ...       ...         ...       ...
# 994634  11715336         25124162      True      True  2026-02-11      1440
# 994635  11715340         25124162      True     False  2026-02-12      1440
# 994636  11715346         25124162      True      True  2026-02-13      1440
# 994637  11715351         25124162      True     False  2026-02-14      1440
# 994638  11715356         25124162      True     False  2026-02-15      1440
#
#         symptoms_both_side_headache  symptoms_one_side_headache  \
# 37                            False                        True
# 38                            False                        True
# 39                            False                        True
# 40                            False                        True
# 41                            False                        True
# ...                             ...                         ...
# 994634                        False                       False
# 994635                        False                       False
# 994636                        False                       False
# 994637                        False                       False
# 994638                        False                       False
#
#         symptoms_pulsating_headache  symptoms_dull_headache     weekday  \
# 37                            False                   False    Dienstag
# 38                            False                   False    Mittwoch
# 39                            False                   False  Donnerstag
# 40                            False                   False     Freitag
# 41                            False                   False     Samstag
# ...                             ...                     ...         ...
# 994634                        False                   False    Mittwoch
# 994635                        False                   False  Donnerstag
# 994636                        False                   False     Freitag
# 994637                        False                   False     Samstag
# 994638                        False                   False     Sonntag
#
#         duration_check
# 37                 540
# 38                 360
# 39                 360
# 40                 840
# 41                  60
# ...                ...
# 994634            1440
# 994635            1440
# 994636            1440
# 994637            1440
# 994638            1440
#
# [1906 rows x 12 columns]

# %%
patient_df = pd.read_csv("dataset/Patients_V1_02-03-2026.csv", on_bad_lines='skip', sep=';', low_memory=False)

# %%
rel_columns=['id_patient', 'date_registration',
       'gender', 'birthyear','entries_app', 'first_app_entry', 'last_app_entry',
       'period_use_app','headache_entries_app', 'migraine_entries_app']

# %%
req_patient=patient_df[rel_columns].copy()

# %%
req_patient.isnull().sum()
# Out:
# id_patient                 0
# date_registration          0
# gender                     0
# birthyear                  0
# entries_app             1193
# first_app_entry         1193
# last_app_entry          1193
# period_use_app          1193
# headache_entries_app    1193
# migraine_entries_app    1193
# dtype: int64

# %%
req_patient.isna().any()
# Out:
# id_patient              False
# date_registration       False
# gender                  False
# birthyear               False
# entries_app              True
# first_app_entry          True
# last_app_entry           True
# period_use_app           True
# headache_entries_app     True
# migraine_entries_app     True
# dtype: bool

# %%
cols = ["date_registration","first_app_entry","last_app_entry"]

req_patient[cols] = req_patient[cols].apply(pd.to_datetime)

# %%
req_patient.head()
# Out:
#    id_patient date_registration    gender  birthyear  entries_app  \
# 0    10007520        2023-06-22  weiblich       1962        517.0
# 1    10022137        2021-10-24  männlich       1964         39.0
# 2    10070992        2023-05-22  weiblich       1998        522.0
# 3    10072456        2025-01-14  weiblich       2001          NaN
# 4    10076150        2020-10-26  weiblich       2000          NaN
#
#   first_app_entry last_app_entry  period_use_app  headache_entries_app  \
# 0      2023-06-21     2024-11-18           517.0                 122.0
# 1      2021-10-23     2021-12-01            40.0                  39.0
# 2      2023-05-13     2025-08-11           822.0                 180.0
# 3             NaT            NaT             NaN                   NaN
# 4             NaT            NaT             NaN                   NaN
#
#    migraine_entries_app
# 0                  10.0
# 1                   0.0
# 2                 133.0
# 3                   NaN
# 4                   NaN

# %%
df_final = req_df.merge(
    req_patient,
    left_on="patient_info_id",
    right_on="id_patient",
    how="left"
)

# %%
df_final.head()
# Out:
#         id  patient_info_id  headache  migraine attack_time  duration  \
# 0  1734884         10007520      True     False  2023-06-21       900
# 1  1744944         10007520      True     False  2023-06-24       300
# 2  1750577         10007520      True     False  2023-06-25       480
# 3  1753437         10007520      True     False  2023-06-26       300
# 4  1757973         10007520      True     False  2023-06-27       900
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                         True                       False
# 1                         True                       False
# 2                         True                       False
# 3                         True                       False
# 4                         True                       False
#
#    symptoms_pulsating_headache  symptoms_dull_headache  ... id_patient  \
# 0                         True                   False  ...   10007520
# 1                         True                   False  ...   10007520
# 2                         True                   False  ...   10007520
# 3                         True                   False  ...   10007520
# 4                         True                    True  ...   10007520
#
#    date_registration    gender birthyear entries_app  first_app_entry  \
# 0         2023-06-22  weiblich      1962       517.0       2023-06-21
# 1         2023-06-22  weiblich      1962       517.0       2023-06-21
# 2         2023-06-22  weiblich      1962       517.0       2023-06-21
# 3         2023-06-22  weiblich      1962       517.0       2023-06-21
# 4         2023-06-22  weiblich      1962       517.0       2023-06-21
#
#    last_app_entry period_use_app headache_entries_app  migraine_entries_app
# 0      2024-11-18          517.0                122.0                  10.0
# 1      2024-11-18          517.0                122.0                  10.0
# 2      2024-11-18          517.0                122.0                  10.0
# 3      2024-11-18          517.0                122.0                  10.0
# 4      2024-11-18          517.0                122.0                  10.0
#
# [5 rows x 22 columns]

# %%
df_final.isnull().sum()
# Out:
# id                             0
# patient_info_id                0
# headache                       0
# migraine                       0
# attack_time                    0
# duration                       0
# symptoms_both_side_headache    0
# symptoms_one_side_headache     0
# symptoms_pulsating_headache    0
# symptoms_dull_headache         0
# weekday                        0
# duration_check                 0
# id_patient                     0
# date_registration              0
# gender                         0
# birthyear                      0
# entries_app                    0
# first_app_entry                0
# last_app_entry                 0
# period_use_app                 0
# headache_entries_app           0
# migraine_entries_app           0
# dtype: int64

# %%
df_final.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 996334    False
# 996335    False
# 996336    False
# 996337    False
# 996338    False
# Length: 996339, dtype: bool

# %%
df_final.drop(columns=["id_patient","id","duration_check"],inplace=True)
len(df_final) == len(req_df)
# Out:
# True

# %%
df_final.head()
# Out:
#    patient_info_id  headache  migraine attack_time  duration  \
# 0         10007520      True     False  2023-06-21       900
# 1         10007520      True     False  2023-06-24       300
# 2         10007520      True     False  2023-06-25       480
# 3         10007520      True     False  2023-06-26       300
# 4         10007520      True     False  2023-06-27       900
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                         True                       False
# 1                         True                       False
# 2                         True                       False
# 3                         True                       False
# 4                         True                       False
#
#    symptoms_pulsating_headache  symptoms_dull_headache   weekday  \
# 0                         True                   False  Mittwoch
# 1                         True                   False   Samstag
# 2                         True                   False   Sonntag
# 3                         True                   False    Montag
# 4                         True                    True  Dienstag
#
#   date_registration    gender  birthyear  entries_app first_app_entry  \
# 0        2023-06-22  weiblich       1962        517.0      2023-06-21
# 1        2023-06-22  weiblich       1962        517.0      2023-06-21
# 2        2023-06-22  weiblich       1962        517.0      2023-06-21
# 3        2023-06-22  weiblich       1962        517.0      2023-06-21
# 4        2023-06-22  weiblich       1962        517.0      2023-06-21
#
#   last_app_entry  period_use_app  headache_entries_app  migraine_entries_app
# 0     2024-11-18           517.0                 122.0                  10.0
# 1     2024-11-18           517.0                 122.0                  10.0
# 2     2024-11-18           517.0                 122.0                  10.0
# 3     2024-11-18           517.0                 122.0                  10.0
# 4     2024-11-18           517.0                 122.0                  10.0

# %%
df_final.columns
# Out:
# Index(['patient_info_id', 'headache', 'migraine', 'attack_time', 'duration',
#        'symptoms_both_side_headache', 'symptoms_one_side_headache',
#        'symptoms_pulsating_headache', 'symptoms_dull_headache', 'weekday',
#        'date_registration', 'gender', 'birthyear', 'entries_app',
#        'first_app_entry', 'last_app_entry', 'period_use_app',
#        'headache_entries_app', 'migraine_entries_app'],
#       dtype='object')

# %%
df_final.dtypes
# Out:
# patient_info_id                         int64
# headache                                 bool
# migraine                                 bool
# attack_time                    datetime64[ns]
# duration                                int64
# symptoms_both_side_headache              bool
# symptoms_one_side_headache               bool
# symptoms_pulsating_headache              bool
# symptoms_dull_headache                   bool
# weekday                              category
# date_registration              datetime64[ns]
# gender                                 object
# birthyear                               int64
# entries_app                           float64
# first_app_entry                datetime64[ns]
# last_app_entry                 datetime64[ns]
# period_use_app                        float64
# headache_entries_app                  float64
# migraine_entries_app                  float64
# dtype: object

# %%
#filter above and equal to 18 years
df_final["age"] = df_final["date_registration"].dt.year - df_final["birthyear"]
df_final = df_final[df_final["age"] >= 18]

# %%
len(df_final)  # the patient removed are 11136
# Out:
# 985203

# %%
df_final["year"] = df_final["attack_time"].dt.year
df_final["month"] = df_final["attack_time"].dt.month

# %%
df_final.head()
# Out:
#    patient_info_id  headache  migraine attack_time  duration  \
# 0         10007520      True     False  2023-06-21       900
# 1         10007520      True     False  2023-06-24       300
# 2         10007520      True     False  2023-06-25       480
# 3         10007520      True     False  2023-06-26       300
# 4         10007520      True     False  2023-06-27       900
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                         True                       False
# 1                         True                       False
# 2                         True                       False
# 3                         True                       False
# 4                         True                       False
#
#    symptoms_pulsating_headache  symptoms_dull_headache   weekday  ...  \
# 0                         True                   False  Mittwoch  ...
# 1                         True                   False   Samstag  ...
# 2                         True                   False   Sonntag  ...
# 3                         True                   False    Montag  ...
# 4                         True                    True  Dienstag  ...
#
#   birthyear entries_app  first_app_entry  last_app_entry period_use_app  \
# 0      1962       517.0       2023-06-21      2024-11-18          517.0
# 1      1962       517.0       2023-06-21      2024-11-18          517.0
# 2      1962       517.0       2023-06-21      2024-11-18          517.0
# 3      1962       517.0       2023-06-21      2024-11-18          517.0
# 4      1962       517.0       2023-06-21      2024-11-18          517.0
#
#   headache_entries_app  migraine_entries_app  age  year  month
# 0                122.0                  10.0   61  2023      6
# 1                122.0                  10.0   61  2023      6
# 2                122.0                  10.0   61  2023      6
# 3                122.0                  10.0   61  2023      6
# 4                122.0                  10.0   61  2023      6
#
# [5 rows x 22 columns]

# %%
df_final.shape
# Out:
# (985203, 22)

# %%
clean_App=pd.read_csv("cleaned_App_Attack_data.csv")

# %%
clean_App.head()
# Out:
#    patient_info_id  headache  migraine attack_time  duration  \
# 0         72741515      True     False  2020-06-08       480
# 1         72741515      True      True  2020-06-09       360
# 2         44203359      True      True  2020-06-19       300
# 3         44203359      True      True  2020-06-20       300
# 4         44203359      True      True  2020-06-21       480
#
#    symptoms_both_side_headache  symptoms_one_side_headache  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                        True
# 3                        False                        True
# 4                        False                        True
#
#    symptoms_pulsating_headache  symptoms_dull_headache   weekday  ...  \
# 0                         True                   False    Montag  ...
# 1                         True                   False  Dienstag  ...
# 2                         True                   False   Freitag  ...
# 3                         True                   False   Samstag  ...
# 4                         True                   False   Sonntag  ...
#
#   birthyear entries_app  first_app_entry  last_app_entry period_use_app  \
# 0      1980      2056.0       2020-06-07      2026-02-15         2080.0
# 1      1980      2056.0       2020-06-07      2026-02-15         2080.0
# 2      1961      1166.0       2020-06-19      2023-10-17         1216.0
# 3      1961      1166.0       2020-06-19      2023-10-17         1216.0
# 4      1961      1166.0       2020-06-19      2023-10-17         1216.0
#
#   headache_entries_app  migraine_entries_app  age  year  month
# 0                174.0                  30.0   40  2020      6
# 1                174.0                  30.0   40  2020      6
# 2                148.0                 117.0   59  2020      6
# 3                148.0                 117.0   59  2020      6
# 4                148.0                 117.0   59  2020      6
#
# [5 rows x 22 columns]

# %%
clean_App.shape
# Out:
# (2970985, 22)

# %%
df_all = pd.concat([df_final,clean_App], ignore_index=True)

# %%
df_all.shape
# Out:
# (3956188, 22)

# %%
df_all.isna().any()
# Out:
# patient_info_id                False
# headache                       False
# migraine                       False
# attack_time                    False
# duration                       False
# symptoms_both_side_headache    False
# symptoms_one_side_headache     False
# symptoms_pulsating_headache    False
# symptoms_dull_headache         False
# weekday                        False
# date_registration              False
# gender                         False
# birthyear                      False
# entries_app                    False
# first_app_entry                False
# last_app_entry                 False
# period_use_app                 False
# headache_entries_app           False
# migraine_entries_app           False
# age                            False
# year                           False
# month                          False
# dtype: bool

# %%
df_all.to_csv("cleaned_data_all.csv", index=False)
